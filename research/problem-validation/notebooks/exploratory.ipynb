# %% [markdown]
# # Problem Validation — Exploratory
#
# 터미널에서 파이프라인 실행:
#
# ```bash
# cd research/problem-validation
# source .venv/bin/activate
# python scripts/run_pipeline.py
# ```
#
# 산출물: `outputs/figures/`, `outputs/tables/`, `outputs/reports/`
